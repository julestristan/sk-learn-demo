# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
import seaborn as sb

diabetes = datasets.load_diabetes()
print(data.feature_names)

x,y = diabetes.data , diabetes.target
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=1)
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

print("model coefs ",model.coef_,"\n model intercept ",model.intercept_
      ,"\n model MSE \n %.2f"%mean_squared_error(y_test,y_pred),"\n model R2 \n %.2f" %r2_score(y_test,y_pred))
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# model coefs  [ -30.62219046 -272.2506057   528.85252681  327.69716891 -581.01973841
#   332.97061365  -27.97314298  139.28036115  665.07667773   61.90517166]
#  model intercept  151.4300932966009
#  model MSE
#  2992.58
#  model R2
#  0.44

# %%
sb.scatterplot(x=y_test,y=y_pred,alpha=0.3)
# Out:
# <Axes: >
